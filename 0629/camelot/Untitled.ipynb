# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# absl-py                           0.12.0
# anyio                             3.1.0
# appnope                           0.1.2
# argon2-cffi                       20.1.0
# astunparse                        1.6.3
# async-generator                   1.10
# attrs                             21.2.0
# autopep8                          1.5.7
# Babel                             2.9.1
# backcall                          0.2.0
# backports.functools-lru-cache     1.6.4
# beautifulsoup4                    4.9.3
# bleach                            3.3.0
# Bottleneck                        1.3.2
# brotlipy                          0.7.0
# cached-property                   1.5.2
# cachetools                        4.2.2
# camelot-py                        0.9.0
# certifi                           2021.5.30
# cffi                              1.14.4
# chardet                           4.0.0
# ...

# %%
import tabula

# Read pdf into list of DataFrame
df = tabula.read_pdf("foo.pdf", pages='1')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-e4cf56100904> in <module>
#       2
#       3 # Read pdf into list of DataFrame
# ----> 4 df = tabula.read_pdf("foo.pdf", pages='1')
#       5 df
#
# AttributeError: module 'tabula' has no attribute 'read_pdf'
